# %% [markdown]
# ## Trabalho Final - Ciência de Dados - Enap / 2020

# %% [markdown]
# ### Apresentação do Dataset

# %%
# Exemplo: O nome do dataset é ZZZZ. Este dataset contém dados referentes a XXXX. Ele é usado para realizar KKKK na organização YYYY.

# %% [markdown]
# #### Link para Download do Dataset

# %%
# Cole o link do dataset aqui
# Exemplo: https://www....

# %% [markdown]
# ### Motivação Pessoal

# %%
# Exemplo: Eu trabalho no órgão XXX que lida diariamente com este tipo de informação
# Exemplo: Eu tenho um hobby que envolve analisar este tipo de informação
# Exemplo: Este é/foi o tema do meu TCC/Mestrado/Doutorado

# %% [markdown]
# ### Investigação

# %% [markdown]
# ### Conclusões e Achados
